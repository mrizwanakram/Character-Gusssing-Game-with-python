# %%
#step# 1:
#import laibearies
import json
import random
import time
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('scrabble.json')
df
# Out:
#                  aa
# 0          aalenien
# 1        aalenienne
# 2       aaleniennes
# 3         aaleniens
# 4               aas
# ...             ...
# 379029   zymotiques
# 379030       zython
# 379031      zythons
# 379032       zythum
# 379033      zythums
#
# [379034 rows x 1 columns]

# %%
# # #checking duplicate vallew
# duplicate_value = df.duplicated(subset = ['aa'])
# print('Total number of duplicated values : ',sum(duplicate_value))

# # #displaying the duplicated values...
# print("dublicated commets are : ")
# df[duplicate_value]

# %%
df.drop_duplicates()
# Out:
#                  aa
# 0          aalenien
# 1        aalenienne
# 2       aaleniennes
# 3         aaleniens
# 4               aas
# ...             ...
# 379029   zymotiques
# 379030       zython
# 379031      zythons
# 379032       zythum
# 379033      zythums
#
# [379033 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379034 entries, 0 to 379033
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   aa      379034 non-null  object
# dtypes: object(1)
# memory usage: 2.9+ MB

# %%
#To store numbers in list name deco from 4 to 12

# dico = df['aa'].to_list()

# %%
dico = df['aa']
for i in dico:
    new = []
    #print(i)
    if len(i) >= 4 and len(i) <= 12:
        #print(i)
        new.append(dico)
        print(i,len(i))
#to show length of every number in output
# Out:
# aalenien 8
# aalenienne 10
# aaleniennes 11
# aaleniens 9
# abaca 5
# abacas 6
# abacost 7
# abacosts 8
# abacule 7
# abacules 8
# abaissa 7
# abaissable 10
# abaissables 11
# abaissai 8
# abaissaient 11
# abaissais 9
# abaissait 9
# abaissames 10
# abaissant 9
# abaissante 10
# abaissantes 11
# abaissants 10
# abaissas 8
# abaissasse 10
# abaissassent 12
# abaissasses 11
# abaissassiez 12
# abaissat 8
# abaissates 10
# abaisse 7
# abaissee 8
# abaissees 9
# abaissement 11
# abaissements 12
# abaissent 9
# abaisser 8
# abaissera 9
# abaisserai 10
# abaisserais 11
# abaisserait 11
# abaisseras 10
# abaisserent 11
# abaisserez 10
# abaisseriez 11
# abaisserions 12
# abaisserons 11
# abaisseront 11
# abaisses 8
# abaisseur 9
# abaisseurs 10
# abaisseuse 10
# abaisseuses 11
# abaissez 8
# abaissiez 9
# abaissions 10
# abaissons 9
# abajoue 7
# abajoues 8
# abalone 7
# abalones 8
# abandon 7
# abandonna 9
# abandonnai 10
# abandonnais 11
# abandonnait 11
# abandonnames 12
# abandonnant 11
# abandonnas 10
# abandonnasse 12
# abandonnat 10
# abandonnates 12
# abandonne 9
# abandonnee 10
# abandonnees 11
# abandonnent 11
# abandonner 10
# abandonnera 11
# abandonnerai 12
# abandonneras 12
# abandonnerez 12
# abandonnes 10
# abandonnez 10
# abandonniez 11
# abandonnions 12
# abandonnique 12
# abandonnons 11
# abandons 8
# abaque 6
# abaques 7
# abasie 6
# abasies 7
# abasourdi 9
# abasourdie 10
# abasourdies 11
# abasourdimes 12
# abasourdir 10
# abasourdira 11
# abasourdirai 12
# abasourdiras 12
# abasourdirez 12
# abasourdis 10
# abasourdisse 12
# abasourdit 10
# abasourdites 12
# abat 4
# abatage 7
# abatages 8
# abreuverait 11
# abreuveras 10
# abreuverent 11
# abreuverez 10
# abreuveriez 11
# abreuverions 12
# abreuverons 11
# abreuveront 11
# abreuves 8
# abreuvez 8
# abreuviez 9
# abreuvions 10
# abreuvoir 9
# abreuvoirs 10
# abreuvons 9
# abreviateur 11
# abreviateurs 12
# abreviatif 10
# abreviatifs 11
# abreviation 11
# abreviations 12
# abreviative 11
# abreviatives 12
# abreviatrice 12
# abri 4
# abria 5
# abriai 6
# abriaient 9
# abriais 7
# abriait 7
# abriames 8
# abriant 7
# abrias 6
# abriasse 8
# abriassent 10
# abriasses 9
# abriassiez 10
# abriassions 11
# abriat 6
# abriates 8
# abribus 7
# abricot 7
# abricote 8
# abricotee 9
# abricotees 10
# abricotes 9
# abricotier 10
# abricotiers 11
# abricotine 10
# abricotines 11
# abricots 8
# abrie 5
# abriee 6
# abriees 7
# abrient 7
# abrier 6
# abriera 7
# abrierai 8
# abrieraient 11
# abrierais 9
# abrierait 9
# abrieras 8
# abrierent 9
# abrierez 8
# abrieriez 9
# abrierions 10
# abrierons 9
# abrieront 9
# abries 6
# abriez 6
# abriiez 7
# abriions 8
# abrions 7
# abris 5
# abrita 6
# abritai 7
# abritaient 10
# abritais 8
# abritait 8
# abritames 9
# abritant 8
# abritas 7
# abritasse 9
# abritassent 11
# abritasses 10
# abritassiez 11
# abritassions 12
# abritat 7
# abritates 9
# abrite 6
# abritee 7
# abritees 8
# abritent 8
# abriter 7
# abritera 8
# abriterai 9
# abriteraient 12
# abriterais 10
# abriterait 10
# abriteras 9
# abriterent 10
# abriterez 9
# abriteriez 10
# abriterions 11
# abriterons 10
# abriteront 10
# abrites 7
# abritez 7
# abritiez 8
# abritions 9
# abritons 8
# abrivent 8
# abrivents 9
# abrogatif 9
# abrogatifs 10
# abrogation 10
# abrogations 11
# abrogative 10
# abrogatives 11
# abrogatoire 11
# abrogatoires 12
# abroge 6
# abrogea 7
# abrogeable 10
# abrogeables 11
# abrogeai 8
# abrogeaient 11
# abrogeais 9
# abrogeait 9
# abrogeames 10
# abrogeant 9
# abrogeas 8
# abrogeasse 10
# abrogeassent 12
# abrogeasses 11
# abrogeassiez 12
# abrogeat 8
# abrogeates 10
# abrogee 7
# abrogees 8
# abrogent 8
# abrogeons 9
# abroger 7
# abrogera 8
# abrogerai 9
# abrogeraient 12
# abrogerais 10
# abrogerait 10
# abrogeras 9
# abrogerent 10
# abrogerez 9
# abrogeriez 10
# abrogerions 11
# abrogerons 10
# abrogeront 10
# abroges 7
# abrogez 7
# abrogiez 8
# abrogions 9
# abrouti 7
# abroutie 8
# abrouties 9
# abroutimes 10
# abroutir 8
# abroutira 9
# abroutirai 10
# abroutirais 11
# abroutirait 11
# abroutiras 10
# abroutirent 11
# abroutirez 10
# abroutiriez 11
# abroutirions 12
# abroutirons 11
# abroutiront 11
# abroutis 8
# abroutissais 12
# abroutissait 12
# abroutissant 12
# abroutisse 10
# abroutissent 12
# abroutisses 11
# abroutissez 11
# abroutissiez 12
# abroutissons 12
# abroutit 8
# abroutites 10
# abrupt 6
# abrupte 7
# abruptement 11
# abruptes 8
# abrupts 7
# abruti 6
# abrutie 7
# abruties 8
# abrutimes 9
# abrutir 7
# abrutira 8
# abrutirai 9
# abrutiraient 12
# abrutirais 10
# abrutirait 10
# abrutiras 9
# abrutirent 10
# abrutirez 9
# abrutiriez 10
# abrutirions 11
# abrutirons 10
# abrutiront 10
# abrutis 7
# abrutissais 11
# abrutissait 11
# abrutissant 11
# abrutissante 12
# abrutissants 12
# abrutisse 9
# abrutissent 11
# abrutisses 10
# abrutisseur 11
# abrutisseurs 12
# abrutisseuse 12
# abrutissez 10
# abrutissiez 11
# abrutissions 12
# abrutissons 11
# abrutit 7
# abrutites 9
# abruzzais 9
# abruzzaise 10
# abruzzaises 11
# abscisse 8
# abscisses 9
# abscons 7
# absconse 8
# absconses 9
# absence 7
# absences 8
# absent 6
# absenta 7
# absentai 8
# absentaient 11
# absentais 9
# absentait 9
# absentames 10
# absentant 9
# absentas 8
# absentasse 10
# absentassent 12
# absentasses 11
# absentassiez 12
# absentat 8
# absentates 10
# absente 7
# absentee 8
# absentees 9
# absenteisme 11
# absenteismes 12
# absenteiste 11
# absenteistes 12
# absentent 9
# absenter 8
# absentera 9
# absenterai 10
# absenterais 11
# absenterait 11
# absenteras 10
# absenterent 11
# absenterez 10
# absenteriez 11
# absenterions 12
# absenterons 11
# absenteront 11
# absentes 8
# absentez 8
# absentiez 9
# absentions 10
# absentons 9
# absents 7
# absidal 7
# absidale 8
# absidales 9
# absidaux 8
# abside 6
# absides 7
# absidial 8
# absidiale 9
# absidiales 10
# absidiaux 9
# absidiole 9
# absidioles 10
# absinthe 8
# absinthee 9
# absinthees 10
# absinthes 9
# absinthisme 11
# absinthismes 12
# absolu 6
# absolue 7
# absolues 8
# absoluite 9
# absoluites 10
# absolument 10
# absolumes 9
# absolurent 10
# absolus 7
# absolusse 9
# absolussent 11
# absolusses 10
# absolussiez 11
# absolussions 12
# absolut 7
# absolutes 9
# absolution 10
# absolutions 11
# absolutisme 11
# absolutismes 12
# absolutiste 11
# absolutistes 12
# absolutoire 11
# absolutoires 12
# absolvaient 11
# absolvais 9
# absolvait 9
# absolvant 9
# absolve 7
# absolvent 9
# absolves 8
# absolvez 8
# absolviez 9
# absolvions 10
# absolvons 9
# absorba 7
# absorbable 10
# absorbables 11
# absorbai 8
# absorbaient 11
# absorbais 9
# absorbait 9
# absorbames 10
# absorbance 10
# absorbances 11
# absorbant 9
# absorbante 10
# absorbantes 11
# absorbants 10
# absorbas 8
# absorbasse 10
# absorbassent 12
# absorbasses 11
# absorbassiez 12
# absorbat 8
# absorbates 10
# absorbe 7
# absorbee 8
# absorbees 9
# absorbent 9
# absorber 8
# absorbera 9
# absorberai 10
# absorberais 11
# absorberait 11
# absorberas 10
# absorberent 11
# absorberez 10
# absorberiez 11
# absorberions 12
# absorberons 11
# absorberont 11
# absorbes 8
# absorbeur 9
# absorbeurs 10
# absorbeuse 10
# absorbeuses 11
# absorbez 8
# absorbiez 9
# absorbions 10
# absorbons 9
# absorption 10
# absorptions 11
# absorptivite 12
# absoudra 8
# absoudrai 9
# absoudraient 12
# absoudrais 10
# absoudrait 10
# absoudras 9
# absoudre 8
# absoudrez 9
# absoudriez 10
# absoudrions 11
# absoudrons 10
# absoudront 10
# absous 6
# absout 6
# absoute 7
# absoutes 8
# absteme 7
# abstemes 8
# abstenaient 11
# abstenais 9
# abstenait 9
# abstenant 9
# abstenez 8
# absteniez 9
# abstenions 10
# abstenir 8
# abstenons 9
# abstention 10
# abstentions 11
# abstenu 7
# abstenue 8
# abstenues 9
# abstenus 8
# abstiendra 10
# abstiendrai 11
# abstiendrais 12
# abstiendrait 12
# abstiendras 11
# abstiendrez 11
# abstiendriez 12
# abstiendrons 12
# abstiendront 12
# abstienne 9
# abstiennent 11
# abstiennes 10
# abstiens 8
# abstient 8
# abstinence 10
# abstinences 11
# abstinent 9
# abstinente 10
# abstinentes 11
# abstinents 10
# abstinmes 9
# abstinrent 10
# abstins 7
# abstinsse 9
# abstinssent 11
# abstinsses 10
# abstinssiez 11
# abstinssions 12
# abstint 7
# abstintes 9
# abstract 8
# abstracteur 11
# abstracteurs 12
# abstractif 10
# abstractifs 11
# abstraction 11
# abstractions 12
# abstractive 11
# abstractives 12
# abstracts 9
# abstraie 8
# abstraient 10
# abstraies 9
# abstraira 9
# abstrairai 10
# abstrairais 11
# abstrairait 11
# abstrairas 10
# abstraire 9
# abstrairez 10
# abstrairiez 11
# abstrairions 12
# abstrairons 11
# abstrairont 11
# abstrais 8
# abstrait 8
# abstraite 9
# abstraites 10
# abstraits 9
# abstrayaient 12
# abstrayais 10
# abstrayait 10
# abstrayant 10
# abstrayez 9
# abstrayiez 10
# abstrayions 11
# abstrayons 10
# abstrus 7
# abstruse 8
# abstruses 9
# absurde 7
# absurdement 11
# absurdes 8
# absurdite 9
# absurdites 10
# abus 4
# abusa 5
# abusai 6
# abusaient 9
# abusais 7
# abusait 7
# abusames 8
# abusant 7
# abusas 6
# abusasse 8
# abusassent 10
# abusasses 9
# abusassiez 10
# abusassions 11
# abusat 6
# abusates 8
# abuse 5
# abusee 6
# abusees 7
# abusent 7
# abuser 6
# abusera 7
# abuserai 8
# abuseraient 11
# abuserais 9
# abuserait 9
# abuseras 8
# abuserent 9
# abuserez 8
# abuseriez 9
# abuserions 10
# abuserons 9
# abuseront 9
# abuses 6
# abuseur 7
# abuseurs 8
# abuseuse 8
# abuseuses 9
# abusez 6
# abusiez 7
# abusif 6
# abusifs 7
# abusions 8
# abusive 7
# abusivement 11
# abusives 8
# abusons 7
# abusus 6
# abuta 5
# abutai 6
# abutaient 9
# abutais 7
# abutait 7
# abutames 8
# abutant 7
# abutas 6
# abutasse 8
# abutassent 10
# abutasses 9
# abutassiez 10
# abutassions 11
# abutat 6
# abutates 8
# abute 5
# abutee 6
# abutees 7
# abutent 7
# abuter 6
# abutera 7
# abuterai 8
# abuteraient 11
# abuterais 9
# abuterait 9
# abuteras 8
# abuterent 9
# abuterez 8
# abuteriez 9
# abuterions 10
# abuterons 9
# abuteront 9
# abutes 6
# abutez 6
# abutiez 7
# abutilon 8
# abutilons 9
# abutions 8
# abutons 7
# abyme 5
# abyssal 7
# abyssale 8
# abyssales 9
# abyssaux 8
# abysse 6
# abysses 7
# abyssin 7
# abyssine 8
# abyssines 9
# abyssinien 10
# abyssinienne 12
# abyssiniens 11
# abyssins 8
# abzyme 6
# abzymes 7
# acabit 6
# acabits 7
# acacia 6
# acacias 7
# academicien 11
# academiciens 12
# academie 8
# academies 9
# academique 10
# academiques 11
# academisable 12
# academisme 10
# academismes 11
# acadianisme 11
# acadianismes 12
# acadien 7
# acadienne 9
# acadiennes 10
# acadiens 8
# acagnarda 9
# acagnardai 10
# acagnardais 11
# acagnardait 11
# acagnardames 12
# acagnardant 11
# acagnardas 10
# acagnardasse 12
# acagnardat 10
# acagnardates 12
# acagnarde 9
# acagnardee 10
# acagnardees 11
# acagnardent 11
# acagnarder 10
# acagnardera 11
# acagnarderai 12
# acagnarderas 12
# acagnarderez 12
# acagnardes 10
# acagnardez 10
# acagnardiez 11
# acagnardions 12
# acagnardons 11
# acajou 6
# acajous 7
# acalculie 9
# acalculies 10
# acalephe 8
# acalephes 9
# acalorique 10
# acaloriques 11
# acanthacee 10
# acanthacees 11
# acanthaire 10
# acanthaires 11
# acanthe 7
# acanthes 8
# acariatre 9
# acariatres 10
# acariatrete 11
# acariatretes 12
# acaricide 9
# acaricides 10
# acarien 7
# acariens 8
# acariose 8
# acarioses 9
# acarpe 6
# acarpes 7
# acarus 6
# acatalepsie 11
# acatalepsies 12
# acatene 7
# acatenes 8
# acaule 6
# acaules 7
# accabla 7
# accablai 8
# accablaient 11
# accablais 9
# accablait 9
# accablames 10
# accablant 9
# accablante 10
# accablantes 11
# accablants 10
# accablas 8
# accablasse 10
# accablassent 12
# accablasses 11
# accablassiez 12
# accablat 8
# accablates 10
# accable 7
# accablee 8
# accablees 9
# accablement 11
# accablements 12
# accablent 9
# accabler 8
# accablera 9
# accablerai 10
# accablerais 11
# accablerait 11
# accableras 10
# accablerent 11
# accablerez 10
# accableriez 11
# accablerions 12
# accablerons 11
# accableront 11
# accables 8
# accablez 8
# accabliez 9
# accablions 10
# accablons 9
# accalmie 8
# accalmies 9
# accapara 8
# accaparai 9
# accaparaient 12
# accaparais 10
# accaparait 10
# accaparames 11
# accaparant 10
# accaparante 11
# accaparantes 12
# accaparants 11
# accaparas 9
# accaparasse 11
# accaparasses 12
# accaparat 9
# accaparates 11
# accapare 8
# accaparee 9
# accaparees 10
# accaparement 12
# accaparent 10
# accaparer 9
# accaparera 10
# accaparerai 11
# accaparerais 12
# accaparerait 12
# accapareras 11
# accaparerent 12
# accaparerez 11
# accapareriez 12
# accaparerons 12
# accapareront 12
# accapares 9
# accapareur 10
# accapareurs 11
# accapareuse 11
# accapareuses 12
# accaparez 9
# accapariez 10
# accaparions 11
# accaparons 10
# accastilla 10
# accastillage 12
# accastillai 11
# accastillais 12
# accastillait 12
# accastillant 12
# accastillas 11
# accastillat 11
# accastille 10
# accastillee 11
# accastillees 12
# accastillent 12
# accastiller 11
# accastillera 12
# accastilles 11
# accastillez 11
# accastilliez 12
# accastillons 12
# acceda 6
# accedai 7
# accedaient 10
# accedais 8
# accedait 8
# accedames 9
# accedant 8
# accedante 9
# accedantes 10
# accedants 9
# accedas 7
# accedasse 9
# accedassent 11
# accedasses 10
# accedassiez 11
# accedassions 12
# accedat 7
# accedates 9
# accede 6
# accedent 8
# acceder 7
# accedera 8
# accederai 9
# accederaient 12
# accederais 10
# accederait 10
# accederas 9
# accederent 10
# accederez 9
# accederiez 10
# accederions 11
# accederons 10
# accederont 10
# accedes 7
# accedez 7
# accediez 8
# accedions 9
# accedons 8
# accelera 8
# accelerai 9
# acceleraient 12
# accelerais 10
# accelerait 10
# accelerames 11
# accelerando 11
# accelerandos 12
# accelerant 10
# acceleras 9
# accelerasse 11
# accelerasses 12
# accelerat 9
# accelerates 11
# accelerateur 12
# acceleration 12
# accelere 8
# acceleree 9
# accelerees 10
# accelerent 10
# accelerer 9
# accelerera 10
# accelererai 11
# accelererais 12
# accelererait 12
# accelereras 11
# accelererent 12
# accelererez 11
# accelereriez 12
# accelererons 12
# accelereront 12
# acceleres 9
# accelerez 9
# acceleriez 10
# accelerine 10
# accelerines 11
# accelerions 11
# accelerons 10
# accent 6
# accenteur 9
# accenteurs 10
# accents 7
# accentua 8
# accentuable 11
# accentuables 12
# accentuai 9
# accentuaient 12
# accentuais 10
# accentuait 10
# accentuames 11
# accentuant 10
# accentuas 9
# accentuasse 11
# accentuasses 12
# accentuat 9
# accentuates 11
# accentuation 12
# accentue 8
# accentuee 9
# accentuees 10
# accentuel 9
# accentuelle 11
# accentuelles 12
# accentuels 10
# accentuent 10
# accentuer 9
# accentuera 10
# accentuerai 11
# accentuerais 12
# accentuerait 12
# accentueras 11
# accentuerent 12
# accentuerez 11
# accentueriez 12
# accentuerons 12
# accentueront 12
# accentues 9
# accentuez 9
# accentuiez 10
# accentuions 11
# accentuons 10
# accepta 7
# acceptable 10
# acceptables 11
# acceptai 8
# acceptaient 11
# acceptais 9
# acceptait 9
# acceptames 10
# acceptant 9
# acceptante 10
# acceptantes 11
# acceptants 10
# acceptas 8
# acceptasse 10
# acceptassent 12
# acceptasses 11
# acceptassiez 12
# acceptat 8
# acceptates 10
# acceptation 11
# acceptations 12
# accepte 7
# acceptee 8
# acceptees 9
# acceptent 9
# accepter 8
# acceptera 9
# accepterai 10
# accepterais 11
# accepterait 11
# accepteras 10
# accepterent 11
# accepterez 10
# accepteriez 11
# accepterions 12
# accepterons 11
# accepteront 11
# acceptes 8
# accepteur 9
# accepteurs 10
# accepteuse 10
# accepteuses 11
# acceptez 8
# acceptiez 9
# acception 9
# acceptions 10
# acceptons 9
# acces 5
# accessible 10
# accessibles 11
# accession 9
# accessions 10
# accessit 8
# accessits 9
# accessoire 10
# accessoires 11
# accessoirisa 12
# accessoirise 12
# accident 8
# accidenta 9
# accidentai 10
# accidentais 11
# accidentait 11
# accidentames 12
# accidentant 11
# accidentas 10
# accidentasse 12
# accidentat 10
# accidentates 12
# accidente 9
# accidentee 10
# accidentees 11
# accidentel 10
# accidentelle 12
# accidentels 11
# accidentent 11
# accidenter 10
# accidentera 11
# accidenterai 12
# accidenteras 12
# accidenterez 12
# accidentes 10
# accidentez 10
# accidentiez 11
# accidentions 12
# accidentons 11
# accidents 9
# accipitride 11
# accipitrides 12
# accise 6
# accises 7
# accisien 8
# accisiens 9
# acclama 7
# acclamai 8
# acclamaient 11
# acclamais 9
# acclamait 9
# acclamames 10
# acclamant 9
# acclamas 8
# acclamasse 10
# acclamassent 12
# acclamasses 11
# acclamassiez 12
# acclamat 8
# acclamates 10
# acclamateur 11
# acclamateurs 12
# acclamation 11
# acclamations 12
# acclamatrice 12
# acclame 7
# acclamee 8
# acclamees 9
# acclament 9
# acclamer 8
# acclamera 9
# acclamerai 10
# acclamerais 11
# acclamerait 11
# acclameras 10
# acclamerent 11
# acclamerez 10
# acclameriez 11
# acclamerions 12
# acclamerons 11
# acclameront 11
# acclames 8
# acclamez 8
# acclamiez 9
# acclamions 10
# acclamons 9
# acclimata 9
# acclimatable 12
# acclimatai 10
# acclimatais 11
# acclimatait 11
# acclimatames 12
# acclimatant 11
# acclimatas 10
# acclimatasse 12
# acclimatat 10
# acclimatates 12
# acclimate 9
# acclimatee 10
# acclimatees 11
# acclimatent 11
# acclimater 10
# acclimatera 11
# acclimaterai 12
# acclimateras 12
# acclimaterez 12
# acclimates 10
# acclimatez 10
# acclimatiez 11
# acclimations 12
# acclimatons 11
# accointa 8
# accointai 9
# accointaient 12
# accointais 10
# accointait 10
# accointames 11
# accointance 11
# accointances 12
# accointant 10
# accointas 9
# accointasse 11
# accointasses 12
# accointat 9
# accointates 11
# accointe 8
# accointee 9
# accointees 10
# accointent 10
# accointer 9
# accointera 10
# accointerai 11
# accointerais 12
# accointerait 12
# accointeras 11
# accointerent 12
# accointerez 11
# accointeriez 12
# accointerons 12
# accointeront 12
# accointes 9
# accointez 9
# accointiez 10
# accointions 11
# accointons 10
# accola 6
# accolade 8
# accolades 9
# accolage 8
# accolages 9
# accolai 7
# accolaient 10
# accolais 8
# accolait 8
# accolames 9
# accolant 8
# accolas 7
# accolasse 9
# accolassent 11
# accolasses 10
# accolassiez 11
# accolassions 12
# accolat 7
# accolates 9
# accole 6
# accolee 7
# accolees 8
# accolement 10
# accolements 11
# accolent 8
# accoler 7
# accolera 8
# accolerai 9
# accoleraient 12
# accolerais 10
# accolerait 10
# accoleras 9
# accolerent 10
# accolerez 9
# accoleriez 10
# accolerions 11
# accolerons 10
# accoleront 10
# accoles 7
# accolez 7
# accoliez 8
# accolions 9
# accolons 8
# accombant 9
# accombante 10
# accombantes 11
# accombants 10
# accommoda 9
# accommodai 10
# accommodais 11
# accommodait 11
# accommodames 12
# accommodant 11
# accommodante 12
# accommodants 12
# accommodas 10
# accommodasse 12
# accommodat 10
# accommodates 12
# accommodats 11
# accommode 9
# accommodee 10
# accommodees 11
# accommodent 11
# accommoder 10
# accommodera 11
# accommoderai 12
# accommoderas 12
# accommoderez 12
# accommodes 10
# accommodez 10
# accommodiez 11
# accommodions 12
# accommodons 11
# accompagna 10
# accompagnai 11
# accompagnais 12
# accompagnait 12
# accompagnant 12
# accompagnas 11
# accompagnat 11
# accompagne 10
# accompagnee 11
# accompagnees 12
# accompagnent 12
# accompagner 11
# accompagnera 12
# accompagnes 11
# accompagnez 11
# accompagniez 12
# accompagnons 12
# accompli 8
# accomplie 9
# accomplies 10
# accomplimes 11
# accomplir 9
# accomplira 10
# accomplirai 11
# accomplirais 12
# accomplirait 12
# accompliras 11
# accomplirent 12
# accomplirez 11
# accompliriez 12
# accomplirons 12
# accompliront 12
# accomplis 9
# accomplisse 11
# accomplisses 12
# accomplissez 12
# accomplit 9
# accomplites 11
# accon 5
# acconage 8
# acconages 9
# acconier 8
# acconiers 9
# accons 6
# accora 6
# accorage 8
# accorages 9
# accorai 7
# accoraient 10
# accorais 8
# accorait 8
# accorames 9
# accorant 8
# accoras 7
# accorasse 9
# accorassent 11
# accorasses 10
# accorassiez 11
# accorassions 12
# accorat 7
# accorates 9
# accord 6
# accorda 7
# accordable 10
# accordables 11
# accordage 9
# accordages 10
# accordai 8
# accordaient 11
# accordailles 12
# accordais 9
# accordait 9
# accordames 10
# accordant 9
# accordante 10
# accordantes 11
# accordants 10
# accordas 8
# accordasse 10
# accordassent 12
# accordasses 11
# accordassiez 12
# accordat 8
# accordates 10
# accorde 7
# accordee 8
# accordees 9
# accordement 11
# accordements 12
# accordent 9
# accordeon 9
# accordeons 10
# accorder 8
# accordera 9
# accorderai 10
# accorderais 11
# accorderait 11
# accorderas 10
# accorderent 11
# accorderez 10
# accorderiez 11
# accorderions 12
# accorderons 11
# accorderont 11
# accordes 8
# accordeur 9
# accordeurs 10
# accordeuse 10
# accordeuses 11
# accordez 8
# accordiez 9
# accordions 10
# accordoir 9
# accordoirs 10
# accordons 9
# accords 7
# accore 6
# accoree 7
# accorees 8
# accorent 8
# accorer 7
# accorera 8
# accorerai 9
# accoreraient 12
# accorerais 10
# accorerait 10
# accoreras 9
# accorerent 10
# accorerez 9
# accoreriez 10
# accorerions 11
# accorerons 10
# accoreront 10
# accores 7
# accorez 7
# accoriez 8
# accorions 9
# accorne 7
# accornee 8
# accornees 9
# accornes 8
# accorons 8
# accort 6
# accorte 7
# accortement 11
# accortes 8
# accortise 9
# accortises 10
# accorts 7
# accosta 7
# accostable 10
# accostables 11
# accostage 9
# accostages 10
# accostai 8
# accostaient 11
# accostais 9
# accostait 9
# accostames 10
# accostant 9
# accostas 8
# accostasse 10
# accostassent 12
# accostasses 11
# accostassiez 12
# accostat 8
# accostates 10
# accoste 7
# accostee 8
# accostees 9
# accostent 9
# accoster 8
# accostera 9
# accosterai 10
# accosterais 11
# accosterait 11
# accosteras 10
# accosterent 11
# accosterez 10
# accosteriez 11
# accosterions 12
# accosterons 11
# accosteront 11
# accostes 8
# accostez 8
# accostiez 9
# accostions 10
# accostons 9
# accot 5
# accota 6
# accotai 7
# accotaient 10
# accotais 8
# accotait 8
# accotames 9
# accotant 8
# accotas 7
# accotasse 9
# accotassent 11
# accotasses 10
# accotassiez 11
# accotassions 12
# accotat 7
# accotates 9
# accote 6
# accotee 7
# accotees 8
# accotement 10
# accotements 11
# accotent 8
# accoter 7
# accotera 8
# accoterai 9
# accoteraient 12
# accoterais 10
# accoterait 10
# accoteras 9
# accoterent 10
# accoterez 9
# accoteriez 10
# accoterions 11
# accoterons 10
# accoteront 10
# accotes 7
# accotez 7
# accotiez 8
# accotions 9
# accotoir 8
# accotoirs 9
# accotons 8
# accots 6
# accoua 6
# accouai 7
# accouaient 10
# accouais 8
# accouait 8
# accouames 9
# accouant 8
# accouas 7
# accouasse 9
# accouassent 11
# accouasses 10
# accouassiez 11
# accouassions 12
# accouat 7
# accouates 9
# accoucha 8
# accouchai 9
# accouchaient 12
# accouchais 10
# accouchait 10
# accouchames 11
# accouchant 10
# accouchas 9
# accouchasse 11
# accouchasses 12
# accouchat 9
# accouchates 11
# accouche 8
# accouchee 9
# accouchees 10
# accouchement 12
# accouchent 10
# accoucher 9
# accouchera 10
# accoucherai 11
# accoucherais 12
# accoucherait 12
# accoucheras 11
# accoucherent 12
# accoucherez 11
# accoucheriez 12
# accoucherons 12
# accoucheront 12
# accouches 9
# accoucheur 10
# accoucheurs 11
# accoucheuse 11
# accoucheuses 12
# accouchez 9
# accouchiez 10
# accouchions 11
# accouchons 10
# accouda 7
# accoudai 8
# accoudaient 11
# accoudais 9
# accoudait 9
# accoudames 10
# accoudant 9
# accoudas 8
# accoudasse 10
# accoudassent 12
# accoudasses 11
# accoudassiez 12
# accoudat 8
# accoudates 10
# accoude 7
# accoudee 8
# accoudees 9
# accoudement 11
# accoudements 12
# accoudent 9
# accouder 8
# accoudera 9
# accouderai 10
# accouderais 11
# accouderait 11
# accouderas 10
# accouderent 11
# accouderez 10
# accouderiez 11
# accouderions 12
# accouderons 11
# accouderont 11
# accoudes 8
# accoudez 8
# accoudiez 9
# accoudions 10
# accoudoir 9
# accoudoirs 10
# accoudons 9
# accoue 6
# accouee 7
# accouees 8
# accouent 8
# accouer 7
# accouera 8
# accouerai 9
# accoueraient 12
# accouerais 10
# accouerait 10
# accoueras 9
# accouerent 10
# accouerez 9
# accoueriez 10
# accouerions 11
# accouerons 10
# accoueront 10
# accoues 7
# accouez 7
# accouiez 8
# accouions 9
# accouons 8
# accoupla 8
# accouplage 10
# accouplages 11
# accouplai 9
# accouplaient 12
# accouplais 10
# accouplait 10
# accouplames 11
# accouplant 10
# accouplas 9
# accouplasse 11
# accouplasses 12
# accouplat 9
# accouplates 11
# accouple 8
# accouplee 9
# accouplees 10
# accouplement 12
# accouplent 10
# accoupler 9
# accouplera 10
# accouplerai 11
# accouplerais 12
# accouplerait 12
# accoupleras 11
# accouplerent 12
# accouplerez 11
# accoupleriez 12
# accouplerons 12
# accoupleront 12
# accouples 9
# accouplez 9
# accoupliez 10
# accouplions 11
# accouplons 10
# accouraient 11
# accourais 9
# accourait 9
# accourant 9
# accourci 8
# accourcie 9
# accourcies 10
# accourcimes 11
# accourcir 9
# accourcira 10
# accourcirai 11
# accourcirais 12
# accourcirait 12
# accourciras 11
# accourcirent 12
# accourcirez 11
# accourciriez 12
# accourcirons 12
# accourciront 12
# accourcis 9
# accourcisse 11
# accourcisses 12
# accourcissez 12
# accourcit 9
# accourcites 11
# accoure 7
# accourent 9
# accoures 8
# accourez 8
# accouriez 9
# accourions 10
# accourir 8
# accourons 9
# accourra 8
# accourrai 9
# accourraient 12
# accourrais 10
# accourrait 10
# accourras 9
# accourrez 9
# accourriez 10
# accourrions 11
# accourrons 10
# accourront 10
# accours 7
# accourt 7
# accouru 7
# accourue 8
# accourues 9
# accourumes 10
# accoururent 11
# accourus 8
# accourusse 10
# accourussent 12
# accourusses 11
# accourussiez 12
# accourut 8
# accourutes 10
# accoutra 8
# accoutrai 9
# accoutraient 12
# accoutrais 10
# accoutrait 10
# accoutrames 11
# accoutrant 10
# accoutras 9
# accoutrasse 11
# accoutrasses 12
# accoutrat 9
# accoutrates 11
# accoutre 8
# accoutree 9
# accoutrees 10
# accoutrement 12
# accoutrent 10
# accoutrer 9
# accoutrera 10
# accoutrerai 11
# accoutrerais 12
# accoutrerait 12
# accoutreras 11
# accoutrerent 12
# accoutrerez 11
# accoutreriez 12
# accoutrerons 12
# accoutreront 12
# accoutres 9
# accoutrez 9
# accoutriez 10
# accoutrions 11
# accoutrons 10
# accoutuma 9
# accoutumai 10
# accoutumais 11
# accoutumait 11
# accoutumames 12
# accoutumance 12
# accoutumant 11
# accoutumas 10
# accoutumasse 12
# accoutumat 10
# accoutumates 12
# accoutume 9
# accoutumee 10
# accoutumees 11
# accoutument 11
# accoutumer 10
# accoutumera 11
# accoutumerai 12
# accoutumeras 12
# accoutumerez 12
# accoutumes 10
# accoutumez 10
# accoutumiez 11
# accoutumions 12
# accoutumons 11
# accouva 7
# accouvage 9
# accouvages 10
# accouvai 8
# accouvaient 11
# accouvais 9
# accouvait 9
# accouvames 10
# accouvant 9
# accouvas 8
# accouvasse 10
# accouvassent 12
# accouvasses 11
# accouvassiez 12
# accouvat 8
# accouvates 10
# accouve 7
# accouvee 8
# accouvees 9
# accouvent 9
# accouver 8
# accouvera 9
# accouverai 10
# accouverais 11
# accouverait 11
# accouveras 10
# accouverent 11
# accouverez 10
# accouveriez 11
# accouverions 12
# accouverons 11
# accouveront 11
# accouves 8
# accouveur 9
# accouveurs 10
# accouveuse 10
# accouveuses 11
# accouvez 8
# accouviez 9
# accouvions 10
# accouvons 9
# accredita 9
# accreditai 10
# accreditais 11
# accreditait 11
# accreditames 12
# accreditant 11
# accreditas 10
# accreditasse 12
# accreditat 10
# accreditates 12
# accredite 9
# accreditee 10
# accreditees 11
# accreditent 11
# accrediter 10
# accreditera 11
# accrediterai 12
# accrediteras 12
# accrediterez 12
# accredites 10
# accrediteur 11
# accrediteurs 12
# accrediteuse 12
# accreditez 10
# accreditiez 11
# accreditif 10
# accreditifs 11
# accreditions 12
# accreditive 11
# accreditives 12
# accreditons 11
# accreditrice 12
# accreen 7
# accreenne 9
# accreennes 10
# accreens 8
# accrescent 10
# accrescente 11
# accrescentes 12
# accrescents 11
# accreta 7
# accretai 8
# accretaient 11
# accretais 9
# accretait 9
# accretames 10
# accretant 9
# accretas 8
# accretasse 10
# accretassent 12
# accretasses 11
# accretassiez 12
# accretat 8
# accretates 10
# accrete 7
# accretee 8
# accretees 9
# accretent 9
# accreter 8
# accretera 9
# accreterai 10
# accreterais 11
# accreterait 11
# accreteras 10
# accreterent 11
# accreterez 10
# accreteriez 11
# accreterions 12
# accreterons 11
# accreteront 11
# accretes 8
# accretez 8
# accretiez 9
# accretion 9
# accretions 10
# accretons 9
# accro 5
# accrobranche 12
# accroc 6
# accrocha 8
# accrochage 10
# accrochages 11
# accrochai 9
# accrochaient 12
# accrochais 10
# accrochait 10
# accrochames 11
# accrochant 10
# accrochante 11
# accrochantes 12
# accrochants 11
# accrochas 9
# accrochasse 11
# accrochasses 12
# accrochat 9
# accrochates 11
# accroche 8
# accrochee 9
# accrochees 10
# accrochement 12
# accrochent 10
# accrocher 9
# accrochera 10
# accrocherai 11
# accrocherais 12
# accrocherait 12
# accrocheras 11
# accrocherent 12
# accrocherez 11
# accrocheriez 12
# accrocherons 12
# accrocheront 12
# accroches 9
# accrocheur 10
# accrocheurs 11
# accrocheuse 11
# accrocheuses 12
# accrochez 9
# accrochiez 10
# accrochions 11
# accrochons 10
# accrocs 7
# accroire 8
# accrois 7
# accroissais 11
# accroissait 11
# accroissant 11
# accroisse 9
# accroissent 11
# accroisses 10
# accroissez 10
# accroissiez 11
# accroissions 12
# accroissons 11
# accroit 7
# accroitra 9
# accroitrai 10
# accroitrais 11
# accroitrait 11
# accroitras 10
# accroitre 9
# accroitrez 10
# accroitriez 11
# accroitrions 12
# accroitrons 11
# accroitront 11
# accros 6
# accroupi 8
# accroupie 9
# accroupies 10
# accroupimes 11
# accroupir 9
# accroupira 10
# accroupirai 11
# accroupirais 12
# accroupirait 12
# accroupiras 11
# accroupirent 12
# accroupirez 11
# accroupiriez 12
# accroupirons 12
# accroupiront 12
# accroupis 9
# accroupisse 11
# accroupisses 12
# accroupissez 12
# accroupit 9
# accroupites 11
# accru 5
# accrue 6
# accrues 7
# accrumes 8
# accrurent 9
# accrus 6
# accrusse 8
# accrussent 10
# accrusses 9
# accrussiez 10
# accrussions 11
# accrut 6
# accrutes 8
# accu 4
# accueil 7
# accueillais 11
# accueillait 11
# accueillant 11
# accueillante 12
# accueillants 12
# accueille 9
# accueillent 11
# accueillera 11
# accueillerai 12
# accueilleras 12
# accueillerez 12
# accueilles 10
# accueillez 10
# accueilli 9
# accueillie 10
# accueillies 11
# accueilliez 11
# accueillimes 12
# accueillions 12
# accueillir 10
# accueillis 10
# accueillisse 12
# accueillit 10
# accueillites 12
# accueillons 11
# accueils 8
# accul 5
# accula 6
# acculai 7
# acculaient 10
# acculais 8
# acculait 8
# acculames 9
# acculant 8
# acculas 7
# acculasse 9
# acculassent 11
# acculasses 10
# acculassiez 11
# acculassions 12
# acculat 7
# acculates 9
# accule 6
# acculee 7
# acculees 8
# acculement 10
# acculements 11
# acculent 8
# acculer 7
# acculera 8
# acculerai 9
# acculeraient 12
# acculerais 10
# acculerait 10
# acculeras 9
# acculerent 10
# acculerez 9
# acculeriez 10
# acculerions 11
# acculerons 10
# acculeront 10
# accules 7
# acculez 7
# acculiez 8
# acculions 9
# acculons 8
# acculs 6
# accultura 9
# acculturai 10
# acculturais 11
# acculturait 11
# acculturames 12
# acculturant 11
# acculturas 10
# acculturasse 12
# acculturat 10
# acculturates 12
# acculture 9
# acculturee 10
# acculturees 11
# acculturent 11
# acculturer 10
# acculturera 11
# acculturerai 12
# accultureras 12
# acculturerez 12
# accultures 10
# acculturez 10
# acculturiez 11
# acculturions 12
# acculturons 11
# accumula 8
# accumulai 9
# accumulaient 12
# accumulais 10
# accumulait 10
# accumulames 11
# accumulant 10
# accumulas 9
# accumulasse 11
# accumulasses 12
# accumulat 9
# accumulates 11
# accumulateur 12
# accumulation 12
# accumule 8
# accumulee 9
# accumulees 10
# accumulent 10
# accumuler 9
# accumulera 10
# accumulerai 11
# accumulerais 12
# accumulerait 12
# accumuleras 11
# accumulerent 12
# accumulerez 11
# accumuleriez 12
# accumulerons 12
# accumuleront 12
# accumules 9
# accumulez 9
# accumuliez 10
# accumulions 11
# accumulons 10
# accus 5
# accusa 6
# accusable 9
# accusables 10
# accusai 7
# accusaient 10
# accusais 8
# accusait 8
# accusames 9
# accusant 8
# accusas 7
# accusasse 9
# accusassent 11
# accusasses 10
# accusassiez 11
# accusassions 12
# accusat 7
# accusates 9
# accusateur 10
# accusateurs 11
# accusatif 9
# accusatifs 10
# accusation 10
# accusations 11
# accusatoire 11
# accusatoires 12
# accusatrice 11
# accusatrices 12
# accuse 6
# accusee 7
# accusees 8
# accusent 8
# accuser 7
# accusera 8
# accuserai 9
# accuseraient 12
# accuserais 10
# accuserait 10
# accuseras 9
# accuserent 10
# accuserez 9
# accuseriez 10
# accuserions 11
# accuserons 10
# accuseront 10
# accuses 7
# accusez 7
# accusiez 8
# accusions 9
# accusons 8
# acellulaire 11
# acellulaires 12
# acensa 6
# acensai 7
# acensaient 10
# acensais 8
# acensait 8
# acensames 9
# acensant 8
# acensas 7
# acensasse 9
# acensassent 11
# acensasses 10
# acensassiez 11
# acensassions 12
# acensat 7
# acensates 9
# acense 6
# acensee 7
# acensees 8
# acensent 8
# acenser 7
# acensera 8
# acenserai 9
# acenseraient 12
# acenserais 10
# acenserait 10
# acenseras 9
# acenserent 10
# acenserez 9
# acenseriez 10
# acenserions 11
# acenserons 10
# acenseront 10
# acenses 7
# acensez 7
# acensiez 8
# acensions 9
# acensons 8
# acephale 8
# acephales 9
# acephalie 9
# acephalies 10
# acera 5
# aceracee 8
# aceracees 9
# acerai 6
# aceraient 9
# acerais 7
# acerait 7
# acerames 8
# acerant 7
# aceras 6
# acerasse 8
# acerassent 10
# acerasses 9
# acerassiez 10
# acerassions 11
# acerat 6
# acerates 8
# acerbe 6
# acerbes 7
# acerbite 8
# acerbites 9
# acere 5
# aceree 6
# acerees 7
# acerent 7
# acerer 6
# acerera 7
# acererai 8
# acereraient 11
# acererais 9
# acererait 9
# acereras 8
# acererent 9
# acererez 8
# acereriez 9
# acererions 10
# acererons 9
# acereront 9
# aceres 6
# acerez 6
# acericole 9
# acericoles 10
# acericulteur 12
# acericulture 12
# aceriez 7
# acerions 8
# acerons 7
# aces 4
# acescence 9
# acescences 10
# acescent 8
# acescente 9
# acescentes 10
# acescents 9
# acetabulaire 12
# acetabule 9
# acetabules 10
# acetabulum 10
# acetabulums 11
# acetal 6
# acetaldehyde 12
# acetals 7
# acetamide 9
# acetamides 10
# acetate 7
# acetates 8
# aceteuse 8
# aceteuses 9
# aceteux 7
# acetifia 8
# acetifiai 9
# acetifiaient 12
# acetifiais 10
# acetifiait 10
# acetifiames 11
# acetifiant 10
# acetifias 9
# acetifiasse 11
# acetifiasses 12
# acetifiat 9
# acetifiates 11
# acetifie 8
# acetifiee 9
# acetifiees 10
# acetifient 10
# acetifier 9
# acetifiera 10
# acetifierai 11
# acetifierais 12
# acetifierait 12
# acetifieras 11
# acetifierent 12
# acetifierez 11
# acetifieriez 12
# acetifierons 12
# acetifieront 12
# acetifies 9
# acetifiez 9
# acetifiiez 10
# acetifiions 11
# acetifions 10
# acetimetre 10
# acetimetres 11
# acetique 8
# acetiques 9
# acetobacter 11
# acetobacters 12
# acetometre 10
# acetometres 11
# acetone 7
# acetonemie 10
# acetonemies 11
# acetonemique 12
# acetones 8
# acetonurie 10
# acetonuries 11
# acetyle 7
# acetylene 9
# acetylenes 10
# acetylenique 12
# acetyles 8
# acetylure 9
# acetylures 10
# achaine 7
# achaines 8
# achala 6
# achalai 7
# achalaient 10
# achalais 8
# achalait 8
# achalames 9
# achalanda 9
# achalandage 11
# achalandages 12
# achalandai 10
# achalandais 11
# achalandait 11
# achalandames 12
# achalandant 11
# achalandas 10
# achalandasse 12
# achalandat 10
# achalandates 12
# achalande 9
# achalandee 10
# achalandees 11
# achalandent 11
# achalander 10
# achalandera 11
# achalanderai 12
# achalanderas 12
# achalanderez 12
# achalandes 10
# achalandez 10
# achalandiez 11
# achalandions 12
# achalandons 11
# achalant 8
# achalante 9
# achalantes 10
# achalants 9
# achalas 7
# achalasie 9
# achalasies 10
# achalasse 9
# achalassent 11
# achalasses 10
# achalassiez 11
# achalassions 12
# achalat 7
# achalates 9
# achale 6
# achalee 7
# achalees 8
# achalent 8
# achaler 7
# achalera 8
# achalerai 9
# achaleraient 12
# achalerais 10
# achalerait 10
# confieras 9
# confierent 10
# confierez 9
# confieriez 10
# confierions 11
# confierons 10
# confieront 10
# confies 7
# confiez 7
# configura 9
# configurai 10
# configurais 11
# configurait 11
# configurames 12
# configurant 11
# configuras 10
# configurasse 12
# configurat 10
# configurates 12
# configure 9
# configuree 10
# configurees 11
# configurent 11
# configurer 10
# configurera 11
# configurerai 12
# configureras 12
# configurerez 12
# configures 10
# configurez 10
# configuriez 11
# configurions 12
# configurons 11
# confiiez 8
# confiions 9
# confimes 8
# confina 7
# confinai 8
# confinaient 11
# confinais 9
# confinait 9
# confinames 10
# confinant 9
# confinas 8
# confinasse 10
# confinassent 12
# confinasses 11
# confinassiez 12
# confinat 8
# confinates 10
# confine 7
# confinee 8
# confinees 9
# confinement 11
# confinements 12
# confinent 9
# confiner 8
# confinera 9
# confinerai 10
# confinerais 11
# confinerait 11
# confineras 10
# confinerent 11
# confinerez 10
# confineriez 11
# confinerions 12
# confinerons 11
# confineront 11
# confines 8
# confinez 8
# confiniez 9
# confinions 10
# confinons 9
# confins 7
# confions 8
# confiote 8
# confiotes 9
# confira 7
# confirai 8
# confiraient 11
# confirais 9
# confirait 9
# confiras 8
# confire 7
# confirent 9
# confirez 8
# confiriez 9
# confirions 10
# confirma 8
# confirmai 9
# confirmaient 12
# confirmais 10
# confirmait 10
# confirmames 11
# confirmand 10
# confirmande 11
# confirmandes 12
# confirmands 11
# confirmant 10
# confirmas 9
# confirmasse 11
# confirmasses 12
# confirmat 9
# confirmates 11
# confirmatif 11
# confirmatifs 12
# confirmation 12
# confirmative 12
# confirme 8
# confirmee 9
# confirmees 10
# confirment 10
# confirmer 9
# confirmera 10
# confirmerai 11
# confirmerais 12
# confirmerait 12
# confirmeras 11
# confirmerent 12
# confirmerez 11
# confirmeriez 12
# confirmerons 12
# confirmeront 12
# confirmes 9
# confirmez 9
# confirmiez 10
# confirmions 11
# confirmons 10
# confirons 9
# confiront 9
# confis 6
# confisaient 11
# confisais 9
# confisait 9
# confisant 9
# confiscable 11
# confiscables 12
# confiscation 12
# confise 7
# confisent 9
# confiserie 10
# confiseries 11
# confises 8
# confiseur 9
# confiseurs 10
# confiseuse 10
# confiseuses 11
# confisez 8
# confisiez 9
# confisions 10
# confisons 9
# confisqua 9
# confisquai 10
# confisquais 11
# confisquait 11
# confisquames 12
# confisquant 11
# confisquas 10
# confisquasse 12
# confisquat 10
# confisquates 12
# confisque 9
# confisquee 10
# confisquees 11
# confisquent 11
# confisquer 10
# confisquera 11
# confisquerai 12
# confisqueras 12
# confisquerez 12
# confisques 10
# confisquez 10
# confisquiez 11
# confisquions 12
# confisquons 11
# confisse 8
# confissent 10
# confisses 9
# confissiez 10
# confissions 11
# confit 6
# confite 7
# confiteor 9
# confites 8
# confits 7
# confiture 9
# confiturerie 12
# confitures 10
# confiturier 11
# confituriere 12
# confituriers 12
# conflictuel 11
# conflictuels 12
# conflit 7
# conflits 8
# conflua 7
# confluai 8
# confluaient 11
# confluais 9
# confluait 9
# confluames 10
# confluant 9
# confluas 8
# confluasse 10
# confluassent 12
# confluasses 11
# confluassiez 12
# confluat 8
# confluates 10
# conflue 7
# confluence 10
# confluences 11
# confluent 9
# confluente 10
# confluentes 11
# confluents 10
# confluer 8
# confluera 9
# confluerai 10
# confluerais 11
# confluerait 11
# conflueras 10
# confluerent 11
# confluerez 10
# conflueriez 11
# confluerions 12
# confluerons 11
# conflueront 11
# conflues 8
# confluez 8
# confluiez 9
# confluions 10
# confluons 9
# confond 7
# confondaient 12
# confondais 10
# confondait 10
# confondant 10
# confondante 11
# confondantes 12
# confondants 11
# confonde 8
# confondent 10
# confondes 9
# confondez 9
# confondiez 10
# confondimes 11
# confondions 11
# confondirent 12
# confondis 9
# confondisse 11
# confondisses 12
# confondit 9
# confondites 11
# confondons 10
# confondra 9
# confondrai 10
# confondrais 11
# confondrait 11
# confondras 10
# confondre 9
# confondrez 10
# confondriez 11
# confondrions 12
# confondrons 11
# confondront 11
# confonds 8
# confondu 8
# confondue 9
# confondues 10
# confondus 9
# conforma 8
# conformai 9
# conformaient 12
# conformais 10
# conformait 10
# conformames 11
# conformant 10
# conformas 9
# conformasse 11
# conformasses 12
# conformat 9
# conformates 11
# conformateur 12
# conformation 12
# conforme 8
# conformee 9
# conformees 10
# conformement 12
# conforment 10
# conformer 9
# conformera 10
# conformerai 11
# conformerais 12
# conformerait 12
# conformeras 11
# conformerent 12
# conformerez 11
# conformeriez 12
# conformerons 12
# conformeront 12
# conformes 9
# conformez 9
# conformiez 10
# conformions 11
# conformisme 11
# conformismes 12
# conformiste 11
# conformistes 12
# conformite 10
# conformites 11
# conformons 10
# confort 7
# conforta 8
# confortable 11
# confortables 12
# confortai 9
# confortaient 12
# confortais 10
# confortait 10
# confortames 11
# confortant 10
# confortas 9
# confortasse 11
# confortasses 12
# confortat 9
# confortates 11
# conforte 8
# confortee 9
# confortees 10
# confortent 10
# conforter 9
# confortera 10
# conforterai 11
# conforterais 12
# conforterait 12
# conforteras 11
# conforterent 12
# conforterez 11
# conforteriez 12
# conforterons 12
# conforteront 12
# confortes 9
# confortez 9
# confortiez 10
# confortions 11
# confortique 11
# confortiques 12
# confortons 10
# conforts 8
# confraternel 12
# confrere 8
# confreres 9
# confrerie 9
# confreries 10
# confrerique 11
# confreriques 12
# confronta 9
# confrontai 10
# confrontais 11
# confrontait 11
# confrontames 12
# confrontant 11
# confrontas 10
# confrontasse 12
# confrontat 10
# confrontates 12
# confronte 9
# confrontee 10
# confrontees 11
# confrontent 11
# confronter 10
# confrontera 11
# confronterai 12
# confronteras 12
# confronterez 12
# confrontes 10
# confrontez 10
# confrontiez 11
# confrontions 12
# confrontons 11
# confuceen 9
# confuceenne 11
# confuceennes 12
# confuceens 10
# confus 6
# confuse 7
# confusement 11
# confuses 8
# confusion 9
# confusionnel 12
# confusions 10
# conga 5
# congai 6
# congais 7
# congas 6
# congaye 7
# congayes 8
# conge 5
# congeable 9
# congeables 10
# congedia 8
# congediable 11
# congediables 12
# congediai 9
# congediaient 12
# congediais 10
# congediait 10
# congediames 11
# congediant 10
# congedias 9
# congediasse 11
# congediasses 12
# congediat 9
# congediates 11
# congedie 8
# congediee 9
# congediees 10
# congediement 12
# congedient 10
# congedier 9
# congediera 10
# congedierai 11
# congedierais 12
# congedierait 12
# congedieras 11
# congedierent 12
# congedierez 11
# congedieriez 12
# congedierons 12
# congedieront 12
# congedies 9
# congediez 9
# congediiez 10
# congediions 11
# congedions 10
# congela 7
# congelable 10
# congelables 11
# congelai 8
# congelaient 11
# congelais 9
# congelait 9
# congelames 10
# congelant 9
# congelas 8
# congelasse 10
# congelassent 12
# congelasses 11
# congelassiez 12
# congelat 8
# congelates 10
# congelateur 11
# congelateurs 12
# congelation 11
# congelations 12
# congele 7
# congelee 8
# congelees 9
# congelent 9
# congeler 8
# congelera 9
# congelerai 10
# congelerais 11
# congelerait 11
# congeleras 10
# congelerent 11
# congelerez 10
# congeleriez 11
# congelerions 12
# congelerons 11
# congeleront 11
# congeles 8
# congelez 8
# congeliez 9
# congelions 10
# congelo 7
# congelons 9
# congelos 8
# congenere 9
# congeneres 10
# congenital 10
# congenitale 11
# congenitales 12
# congenitaux 11
# congere 7
# congeres 8
# conges 6
# congestif 9
# congestifs 10
# congestion 10
# congestionna 12
# congestionne 12
# congestions 11
# congestive 10
# congestives 11
# congiaire 9
# congiaires 10
# conglomera 10
# conglomerai 11
# conglomerais 12
# conglomerait 12
# conglomeral 11
# conglomerale 12
# conglomerant 12
# conglomeras 11
# conglomerat 11
# conglomerats 12
# conglomeraux 12
# conglomere 10
# conglomeree 11
# conglomerees 12
# conglomerent 12
# conglomerer 11
# conglomerera 12
# conglomeres 11
# conglomerez 11
# conglomeriez 12
# conglomerons 12
# conglutina 10
# conglutinai 11
# conglutinais 12
# conglutinait 12
# conglutinant 12
# conglutinas 11
# conglutinat 11
# conglutine 10
# conglutinee 11
# conglutinees 12
# conglutinent 12
# conglutiner 11
# conglutinera 12
# conglutines 11
# conglutinez 11
# conglutiniez 12
# conglutinons 12
# congolais 9
# congolaise 10
# congolaises 11
# congratula 10
# congratulai 11
# congratulais 12
# congratulait 12
# congratulant 12
# congratulas 11
# congratulat 11
# congratule 10
# congratulee 11
# congratulees 12
# congratulent 12
# congratuler 11
# congratulera 12
# congratules 11
# congratulez 11
# congratuliez 12
# congratulons 12
# congre 6
# congrea 7
# congreai 8
# congreaient 11
# congreais 9
# congreait 9
# congreames 10
# congreant 9
# congreas 8
# congreasse 10
# congreassent 12
# congreasses 11
# congreassiez 12
# congreat 8
# congreates 10
# congree 7
# congreee 8
# congreees 9
# congreent 9
# congreer 8
# congreera 9
# congreerai 10
# congreerais 11
# congreerait 11
# congreeras 10
# congreerent 11
# congreerez 10
# congreeriez 11
# congreerions 12
# congreerons 11
# congreeront 11
# congrees 8
# congreez 8
# congregation 12
# congreiez 9
# congreions 10
# congreons 9
# congres 7
# congressiste 12
# congru 6
# congrue 7
# congruence 10
# congruences 11
# congruent 9
# congruente 10
# congruentes 11
# congruents 10
# congrues 8
# congruite 9
# congruites 10
# congrument 10
# congrus 7
# coniacien 9
# coniacienne 11
# coniaciennes 12
# coniaciens 10
# conicine 8
# conicines 9
# conicite 8
# conicites 9
# conidie 7
# conidies 8
# conifere 8
# coniferes 9
# conique 7
# coniques 8
# conirostre 10
# conirostres 11
# conjectura 10
# conjecturai 11
# conjecturais 12
# conjecturait 12
# conjectural 11
# conjecturale 12
# conjecturant 12
# conjecturas 11
# conjecturat 11
# conjecturaux 12
# conjecture 10
# conjecturee 11
# conjecturees 12
# conjecturent 12
# conjecturer 11
# conjecturera 12
# conjectures 11
# conjecturez 11
# conjecturiez 12
# conjecturons 12
# conjoignais 11
# conjoignait 11
# conjoignant 11
# conjoigne 9
# conjoignent 11
# conjoignes 10
# conjoignez 10
# conjoigniez 11
# conjoignimes 12
# conjoignions 12
# conjoignis 10
# conjoignisse 12
# conjoignit 10
# conjoignites 12
# conjoignons 11
# conjoindra 10
# conjoindrai 11
# conjoindrais 12
# conjoindrait 12
# conjoindras 11
# conjoindre 10
# conjoindrez 11
# conjoindriez 12
# conjoindrons 12
# conjoindront 12
# conjoins 8
# conjoint 8
# conjointe 9
# conjointes 10
# conjoints 9
# conjoncteur 11
# conjoncteurs 12
# conjonctif 10
# conjonctifs 11
# conjonction 11
# conjonctions 12
# conjonctival 12
# conjonctive 11
# conjonctives 12
# conjoncture 11
# conjoncturel 12
# conjonctures 12
# conjugable 10
# conjugables 11
# conjugaison 11
# conjugaisons 12
# conjugal 8
# conjugale 9
# conjugales 10
# conjugalite 11
# conjugalites 12
# conjugateur 11
# conjugateurs 12
# conjugaux 9
# conjugua 8
# conjuguai 9
# conjuguaient 12
# conjuguais 10
# conjuguait 10
# conjuguames 11
# conjuguant 10
# conjuguas 9
# conjuguasse 11
# conjuguasses 12
# conjuguat 9
# conjuguates 11
# conjugue 8
# conjuguee 9
# conjuguees 10
# conjuguent 10
# conjuguer 9
# conjuguera 10
# conjuguerai 11
# conjuguerais 12
# conjuguerait 12
# conjugueras 11
# conjuguerent 12
# conjuguerez 11
# conjugueriez 12
# conjuguerons 12
# conjugueront 12
# conjugues 9
# conjuguez 9
# conjuguiez 10
# conjuguions 11
# conjuguons 10
# conjungo 8
# conjungos 9
# conjura 7
# conjurai 8
# conjuraient 11
# conjurais 9
# conjurait 9
# conjurames 10
# conjurant 9
# conjuras 8
# conjurasse 10
# conjurassent 12
# conjurasses 11
# conjurassiez 12
# conjurat 8
# conjurates 10
# conjurateur 11
# conjurateurs 12
# conjuration 11
# conjurations 12
# conjuratoire 12
# conjuratrice 12
# conjure 7
# conjuree 8
# conjurees 9
# conjurent 9
# conjurer 8
# conjurera 9
# conjurerai 10
# conjurerais 11
# conjurerait 11
# conjureras 10
# conjurerent 11
# conjurerez 10
# conjureriez 11
# conjurerions 12
# conjurerons 11
# conjureront 11
# conjures 8
# conjurez 8
# conjuriez 9
# conjurions 10
# conjurons 9
# connais 7
# connaissable 12
# connaissais 11
# connaissait 11
# connaissance 12
# connaissant 11
# connaisse 9
# connaissent 11
# connaisses 10
# connaisseur 11
# connaisseurs 12
# connaisseuse 12
# connaissez 10
# connaissiez 11
# connaissions 12
# connaissons 11
# connait 7
# connaitra 9
# connaitrai 10
# connaitrais 11
# connaitrait 11
# connaitras 10
# connaitre 9
# connaitrez 10
# connaitriez 11
# connaitrions 12
# connaitrons 11
# connaitront 11
# connard 7
# connarde 8
# connardes 9
# connards 8
# connasse 8
# connasses 9
# conne 5
# conneau 7
# conneaux 8
# connecta 8
# connectable 11
# connectables 12
# connectai 9
# connectaient 12
# connectais 10
# connectait 10
# connectames 11
# connectant 10
# connectas 9
# connectasse 11
# connectasses 12
# connectat 9
# connectates 11
# connecte 8
# connectee 9
# connectees 10
# connectent 10
# connecter 9
# connectera 10
# connecterai 11
# connecterais 12
# connecterait 12
# connecteras 11
# connecterent 12
# connecterez 11
# connecteriez 12
# connecterons 12
# connecteront 12
# connectes 9
# connecteur 10
# connecteurs 11
# connectez 9
# connecticien 12
# connectiez 10
# connectif 9
# connectifs 10
# connections 11
# connectique 11
# connectiques 12
# connective 10
# connectives 11
# connectivite 12
# connectons 10
# connement 9
# connerie 8
# conneries 9
# connes 6
# connetable 10
# connetables
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-b0ea4ed3ce96> in <module>
#       6         #print(i)
#       7         new.append(dico)
# ----> 8         print(i,len(i))
#       9 #to show length of every number in output
#
# ~\New folder\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\New folder\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\New folder\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\New folder\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
dico = df['aa'].to_list()
dico
# Out:
# ['aalenien',
#  'aalenienne',
#  'aaleniennes',
#  'aaleniens',
#  'aas',
#  'abaca',
#  'abacas',
#  'abacost',
#  'abacosts',
#  'abacule',
#  'abacules',
#  'abaissa',
#  'abaissable',
#  'abaissables',
#  'abaissai',
#  'abaissaient',
#  'abaissais',
#  'abaissait',
#  'abaissames',
#  'abaissant',
#  'abaissante',
#  'abaissantes',
#  'abaissants',
#  'abaissas',
#  'abaissasse',
#  'abaissassent',
#  'abaissasses',
#  'abaissassiez',
#  'abaissassions',
#  'abaissat',
#  'abaissates',
#  'abaisse',
#  'abaissee',
#  'abaissees',
#  'abaissement',
#  'abaissements',
#  'abaissent',
#  'abaisser',
#  'abaissera',
#  'abaisserai',
#  'abaisseraient',
#  'abaisserais',
#  'abaisserait',
#  'abaisseras',
#  'abaisserent',
#  'abaisserez',
#  'abaisseriez',
#  'abaisserions',
#  'abaisserons',
#  'abaisseront',
#  'abaisses',
#  'abaisseur',
#  'abaisseurs',
#  'abaisseuse',
#  'abaisseuses',
#  'abaissez',
#  'abaissiez',
#  'abaissions',
#  'abaissons',
#  'abajoue',
#  'abajoues',
#  'abalone',
#  'abalones',
#  'abandon',
#  'abandonna',
#  'abandonnai',
#  'abandonnaient',
#  'abandonnais',
#  'abandonnait',
#  'abandonnames',
#  'abandonnant',
#  'abandonnas',
#  'abandonnasse',
#  'abandonnassent',
#  'abandonnasses',
#  'abandonnassiez',
#  'abandonnassions',
#  'abandonnat',
#  'abandonnataire',
#  'abandonnataires',
#  'abandonnates',
#  'abandonnateur',
#  'abandonnateurs',
#  'abandonnatrice',
#  'abandonnatrices',
#  'abandonne',
#  'abandonnee',
#  'abandonnees',
#  'abandonnement',
#  'abandonnements',
#  'abandonnent',
#  'abandonner',
#  'abandonnera',
#  'abandonnerai',
#  'abandonneraient',
#  'abandonnerais',
#  'abandonnerait',
#  'abandonneras',
#  'abandonnerent',
#  'abandonnerez',
#  'abandonneriez',
#  'abandonnerions',
#  'abandonnerons',
#  'abandonneront',
#  'abandonnes',
#  'abandonnez',
#  'abandonniez',
#  'abandonnions',
#  'abandonnique',
#  'abandonniques',
#  'abandonnons',
#  'abandons',
#  'abaque',
#  'abaques',
#  'abasie',
#  'abasies',
#  'abasourdi',
#  'abasourdie',
#  'abasourdies',
#  'abasourdimes',
#  'abasourdir',
#  'abasourdira',
#  'abasourdirai',
#  'abasourdiraient',
#  'abasourdirais',
#  'abasourdirait',
#  'abasourdiras',
#  'abasourdirent',
#  'abasourdirez',
#  'abasourdiriez',
#  'abasourdirions',
#  'abasourdirons',
#  'abasourdiront',
#  'abasourdis',
#  'abasourdissais',
#  'abasourdissait',
#  'abasourdissant',
#  'abasourdissante',
#  'abasourdissants',
#  'abasourdisse',
#  'abasourdissent',
#  'abasourdisses',
#  'abasourdissez',
#  'abasourdissiez',
#  'abasourdissions',
#  'abasourdissons',
#  'abasourdit',
#  'abasourdites',
#  'abat',
#  'abatage',
#  'abatages',
#  'abatant',
#  'abatants',
#  'abatardi',
#  'abatardie',
#  'abatardies',
#  'abatardimes',
#  'abatardir',
#  'abatardira',
#  'abatardirai',
#  'abatardiraient',
#  'abatardirais',
#  'abatardirait',
#  'abatardiras',
#  'abatardirent',
#  'abatardirez',
#  'abatardiriez',
#  'abatardirions',
#  'abatardirons',
#  'abatardiront',
#  'abatardis',
#  'abatardissaient',
#  'abatardissais',
#  'abatardissait',
#  'abatardissant',
#  'abatardisse',
#  'abatardissement',
#  'abatardissent',
#  'abatardisses',
#  'abatardissez',
#  'abatardissiez',
#  'abatardissions',
#  'abatardissons',
#  'abatardit',
#  'abatardites',
#  'abatee',
#  'abatees',
#  'abatis',
#  'abats',
#  'abattable',
#  'abattables',
#  'abattage',
#  'abattages',
#  'abattaient',
#  'abattais',
#  'abattait',
#  'abattant',
#  'abattants',
#  'abatte',
#  'abattee',
#  'abattees',
#  'abattement',
#  'abattements',
#  'abattent',
#  'abattes',
#  'abatteur',
#  'abatteurs',
#  'abatteuse',
#  'abatteuses',
#  'abattez',
#  'abattiez',
#  'abattimes',
#  'abattions',
#  'abattirent',
#  'abattis',
#  'abattisse',
#  'abattissent',
#  'abattisses',
#  'abattissiez',
#  'abattissions',
#  'abattit',
#  'abattites',
#  'abattoir',
#  'abattoirs',
#  'abattons',
#  'abattra',
#  'abattrai',
#  'abattraient',
#  'abattrais',
#  'abattrait',
#  'abattras',
#  'abattre',
#  'abattrez',
#  'abattriez',
#  'abattrions',
#  'abattrons',
#  'abattront',
#  'abattu',
#  'abattue',
#  'abattues',
#  'abatture',
#  'abattures',
#  'abattus',
#  'abbasside',
#  'abbassides',
#  'abbatial',
#  'abbatiale',
#  'abbatiales',
#  'abbatiaux',
#  'abbaye',
#  'abbayes',
#  'abbe',
#  'abbes',
#  'abbesse',
#  'abbesses',
#  'abbevillien',
#  'abbevillienne',
#  'abbevilliennes',
#  'abbevilliens',
#  'abceda',
#  'abcedai',
#  'abcedaient',
#  'abcedais',
#  'abcedait',
#  'abcedames',
#  'abcedant',
#  'abcedas',
#  'abcedasse',
#  'abcedassent',
#  'abcedasses',
#  'abcedassiez',
#  'abcedassions',
#  'abcedat',
#  'abcedates',
#  'abcede',
#  'abcedee',
#  'abcedees',
#  'abcedent',
#  'abceder',
#  'abcedera',
#  'abcederai',
#  'abcederaient',
#  'abcederais',
#  'abcederait',
#  'abcederas',
#  'abcederent',
#  'abcederez',
#  'abcederiez',
#  'abcederions',
#  'abcederons',
#  'abcederont',
#  'abcedes',
#  'abcedez',
#  'abcediez',
#  'abcedions',
#  'abcedons',
#  'abces',
#  'abdicataire',
#  'abdicataires',
#  'abdication',
#  'abdications',
#  'abdiqua',
#  'abdiquai',
#  'abdiquaient',
#  'abdiquais',
#  'abdiquait',
#  'abdiquames',
#  'abdiquant',
#  'abdiquas',
#  'abdiquasse',
#  'abdiquassent',
#  'abdiquasses',
#  'abdiquassiez',
#  'abdiquassions',
#  'abdiquat',
#  'abdiquates',
#  'abdique',
#  'abdiquee',
#  'abdiquees',
#  'abdiquent',
#  'abdiquer',
#  'abdiquera',
#  'abdiquerai',
#  'abdiqueraient',
#  'abdiquerais',
#  'abdiquerait',
#  'abdiqueras',
#  'abdiquerent',
#  'abdiquerez',
#  'abdiqueriez',
#  'abdiquerions',
#  'abdiquerons',
#  'abdiqueront',
#  'abdiques',
#  'abdiquez',
#  'abdiquiez',
#  'abdiquions',
#  'abdiquons',
#  'abdomen',
#  'abdomens',
#  'abdominal',
#  'abdominale',
#  'abdominales',
#  'abdominaux',
#  'abdos',
#  'abducteur',
#  'abducteurs',
#  'abduction',
#  'abductions',
#  'abductrice',
#  'abductrices',
#  'abecedaire',
#  'abecedaires',
#  'abee',
#  'abees',
#  'abeille',
#  'abeiller',
#  'abeillere',
#  'abeilleres',
#  'abeillers',
#  'abeilles',
#  'abelia',
#  'abelias',
#  'abelie',
#  'abelien',
#  'abelienne',
#  'abeliennes',
#  'abeliens',
#  'abelies',
#  'abenaquis',
#  'abenaquise',
#  'abenaquises',
#  'aber',
#  'aberra',
#  'aberrai',
#  'aberraient',
#  'aberrais',
#  'aberrait',
#  'aberrames',
#  'aberrance',
#  'aberrances',
#  'aberrant',
#  'aberrante',
#  'aberrantes',
#  'aberrants',
#  'aberras',
#  'aberrasse',
#  'aberrassent',
#  'aberrasses',
#  'aberrassiez',
#  'aberrassions',
#  'aberrat',
#  'aberrates',
#  'aberration',
#  'aberrations',
#  'aberre',
#  'aberrent',
#  'aberrer',
#  'aberrera',
#  'aberrerai',
#  'aberreraient',
#  'aberrerais',
#  'aberrerait',
#  'aberreras',
#  'aberrerent',
#  'aberrerez',
#  'aberreriez',
#  'aberrerions',
#  'aberrerons',
#  'aberreront',
#  'aberres',
#  'aberrez',
#  'aberriez',
#  'aberrions',
#  'aberrons',
#  'abers',
#  'abessif',
#  'abessifs',
#  'abeti',
#  'abetie',
#  'abeties',
#  'abetimes',
#  'abetir',
#  'abetira',
#  'abetirai',
#  'abetiraient',
#  'abetirais',
#  'abetirait',
#  'abetiras',
#  'abetirent',
#  'abetirez',
#  'abetiriez',
#  'abetirions',
#  'abetirons',
#  'abetiront',
#  'abetis',
#  'abetissaient',
#  'abetissais',
#  'abetissait',
#  'abetissant',
#  'abetissante',
#  'abetissantes',
#  'abetissants',
#  'abetisse',
#  'abetissement',
#  'abetissements',
#  'abetissent',
#  'abetisses',
#  'abetissez',
#  'abetissiez',
#  'abetissions',
#  'abetissons',
#  'abetit',
#  'abetites',
#  'abhorra',
#  'abhorrai',
#  'abhorraient',
#  'abhorrais',
#  'abhorrait',
#  'abhorrames',
#  'abhorrant',
#  'abhorras',
#  'abhorrasse',
#  'abhorrassent',
#  'abhorrasses',
#  'abhorrassiez',
#  'abhorrassions',
#  'abhorrat',
#  'abhorrates',
#  'abhorre',
#  'abhorree',
#  'abhorrees',
#  'abhorrent',
#  'abhorrer',
#  'abhorrera',
#  'abhorrerai',
#  'abhorreraient',
#  'abhorrerais',
#  'abhorrerait',
#  'abhorreras',
#  'abhorrerent',
#  'abhorrerez',
#  'abhorreriez',
#  'abhorrerions',
#  'abhorrerons',
#  'abhorreront',
#  'abhorres',
#  'abhorrez',
#  'abhorriez',
#  'abhorrions',
#  'abhorrons',
#  'abidjanais',
#  'abidjanaise',
#  'abidjanaises',
#  'abies',
#  'abietacee',
#  'abietacees',
#  'abietin',
#  'abietine',
#  'abietinee',
#  'abietinees',
#  'abietines',
#  'abietins',
#  'abima',
#  'abimai',
#  'abimaient',
#  'abimais',
#  'abimait',
#  'abimames',
#  'abimant',
#  'abimas',
#  'abimasse',
#  'abimassent',
#  'abimasses',
#  'abimassiez',
#  'abimassions',
#  'abimat',
#  'abimates',
#  'abime',
#  'abimee',
#  'abimees',
#  'abiment',
#  'abimer',
#  'abimera',
#  'abimerai',
#  'abimeraient',
#  'abimerais',
#  'abimerait',
#  'abimeras',
#  'abimerent',
#  'abimerez',
#  'abimeriez',
#  'abimerions',
#  'abimerons',
#  'abimeront',
#  'abimes',
#  'abimez',
#  'abimiez',
#  'abimions',
#  'abimons',
#  'abiogenese',
#  'abiogeneses',
#  'abiotique',
#  'abiotiques',
#  'abitibien',
#  'abitibienne',
#  'abitibiennes',
#  'abitibiens',
#  'abject',
#  'abjecte',
#  'abjectement',
#  'abjectes',
#  'abjection',
#  'abjections',
#  'abjects',
#  'abjura',
#  'abjurai',
#  'abjuraient',
#  'abjurais',
#  'abjurait',
#  'abjurames',
#  'abjurant',
#  'abjuras',
#  'abjurasse',
#  'abjurassent',
#  'abjurasses',
#  'abjurassiez',
#  'abjurassions',
#  'abjurat',
#  'abjurates',
#  'abjuration',
#  'abjurations',
#  'abjuratoire',
#  'abjuratoires',
#  'abjure',
#  'abjuree',
#  'abjurees',
#  'abjurent',
#  'abjurer',
#  'abjurera',
#  'abjurerai',
#  'abjureraient',
#  'abjurerais',
#  'abjurerait',
#  'abjureras',
#  'abjurerent',
#  'abjurerez',
#  'abjureriez',
#  'abjurerions',
#  'abjurerons',
#  'abjureront',
#  'abjures',
#  'abjurez',
#  'abjuriez',
#  'abjurions',
#  'abjurons',
#  'abkhaze',
#  'abkhazes',
#  'ablactation',
#  'ablactations',
#  'ablastine',
#  'ablastines',
#  'ablata',
#  'ablatai',
#  'ablataient',
#  'ablatais',
#  'ablatait',
#  'ablatames',
#  'ablatant',
#  'ablatas',
#  'ablatasse',
#  'ablatassent',
#  'ablatasses',
#  'ablatassiez',
#  'ablatassions',
#  'ablatat',
#  'ablatates',
#  'ablate',
#  'ablatee',
#  'ablatees',
#  'ablatent',
#  'ablater',
#  'ablatera',
#  'ablaterai',
#  'ablateraient',
#  'ablaterais',
#  'ablaterait',
#  'ablateras',
#  'ablaterent',
#  'ablaterez',
#  'ablateriez',
#  'ablaterions',
#  'ablaterons',
#  'ablateront',
#  'ablates',
#  'ablatez',
#  'ablatiez',
#  'ablatif',
#  'ablatifs',
#  'ablation',
#  'ablations',
#  'ablative',
#  'ablatives',
#  'ablatons',
#  'able',
#  'ablegat',
#  'ablegation',
#  'ablegations',
#  'ablegats',
#  'ableret',
#  'ablerets',
#  'ables',
#  'ablette',
#  'ablettes',
#  'ablier',
#  'abliers',
#  'ablution',
#  'ablutions',
#  'abnegation',
#  'abnegations',
#  'aboi',
#  'aboie',
#  'aboiement',
#  'aboiements',
#  'aboient',
#  'aboiera',
#  'aboierai',
#  'aboieraient',
#  'aboierais',
#  'aboierait',
#  'aboieras',
#  'aboierez',
#  'aboieriez',
#  'aboierions',
#  'aboierons',
#  'aboieront',
#  'aboies',
#  'abois',
#  'aboiteau',
#  'aboiteaux',
#  'aboli',
#  'abolie',
#  'abolies',
#  'abolimes',
#  'abolir',
#  'abolira',
#  'abolirai',
#  'aboliraient',
#  'abolirais',
#  'abolirait',
#  'aboliras',
#  'abolirent',
#  'abolirez',
#  'aboliriez',
#  'abolirions',
#  'abolirons',
#  'aboliront',
#  'abolis',
#  'abolissaient',
#  'abolissais',
#  'abolissait',
#  'abolissant',
#  'abolisse',
#  'abolissent',
#  'abolisses',
#  'abolissez',
#  'abolissiez',
#  'abolissions',
#  'abolissons',
#  'abolit',
#  'abolites',
#  'abolitif',
#  'abolitifs',
#  'abolition',
#  'abolitionnisme',
#  'abolitionnismes',
#  'abolitionniste',
#  'abolitionnistes',
#  'abolitions',
#  'abolitive',
#  'abolitives',
#  'abomina',
#  'abominable',
#  'abominablement',
#  'abominables',
#  'abominai',
#  'abominaient',
#  'abominais',
#  'abominait',
#  'abominames',
#  'abominant',
#  'abominas',
#  'abominasse',
#  'abominassent',
#  'abominasses',
#  'abominassiez',
#  'abominassions',
#  'abominat',
#  'abominates',
#  'abomination',
#  'abominations',
#  'abomine',
#  'abominee',
#  'abominees',
#  'abominent',
#  'abominer',
#  'abominera',
#  'abominerai',
#  'abomineraient',
#  'abominerais',
#  'abominerait',
#  'abomineras',
#  'abominerent',
#  'abominerez',
#  'abomineriez',
#  'abominerions',
#  'abominerons',
#  'abomineront',
#  'abomines',
#  'abominez',
#  'abominiez',
#  'abominions',
#  'abominons',
#  'abonda',
#  'abondai',
#  'abondaient',
#  'abondais',
#  'abondait',
#  'abondames',
#  'abondamment',
#  'abondance',
#  'abondances',
#  'abondanciste',
#  'abondancistes',
#  'abondant',
#  'abondante',
#  'abondantes',
#  'abondants',
#  'abondas',
#  'abondasse',
#  'abondassent',
#  'abondasses',
#  'abondassiez',
#  'abondassions',
#  'abondat',
#  'abondates',
#  'abonde',
#  'abondee',
#  'abondees',
#  'abondement',
#  'abondements',
#  'abondent',
#  'abonder',
#  'abondera',
#  'abonderai',
#  'abonderaient',
#  'abonderais',
#  'abonderait',
#  'abonderas',
#  'abonderent',
#  'abonderez',
#  'abonderiez',
#  'abonderions',
#  'abonderons',
#  'abonderont',
#  'abondes',
#  'abondez',
#  'abondiez',
#  'abondions',
#  'abondons',
#  'abonna',
#  'abonnai',
#  'abonnaient',
#  'abonnais',
#  'abonnait',
#  'abonnames',
#  'abonnant',
#  'abonnas',
#  'abonnasse',
#  'abonnassent',
#  'abonnasses',
#  'abonnassiez',
#  'abonnassions',
#  'abonnat',
#  'abonnates',
#  'abonne',
#  'abonnee',
#  'abonnees',
#  'abonnement',
#  'abonnements',
#  'abonnent',
#  'abonner',
#  'abonnera',
#  'abonnerai',
#  'abonneraient',
#  'abonnerais',
#  'abonnerait',
#  'abonneras',
#  'abonnerent',
#  'abonnerez',
#  'abonneriez',
#  'abonnerions',
#  'abonnerons',
#  'abonneront',
#  'abonnes',
#  'abonnez',
#  'abonni',
#  'abonnie',
#  'abonnies',
#  'abonniez',
#  'abonnimes',
#  'abonnions',
#  'abonnir',
#  'abonnira',
#  'abonnirai',
#  'abonniraient',
#  'abonnirais',
#  'abonnirait',
#  'abonniras',
#  'abonnirent',
#  'abonnirez',
#  'abonniriez',
#  'abonnirions',
#  'abonnirons',
#  'abonniront',
#  'abonnis',
#  'abonnissaient',
#  'abonnissais',
#  'abonnissait',
#  'abonnissant',
#  'abonnisse',
#  'abonnissement',
#  'abonnissements',
#  'abonnissent',
#  'abonnisses',
#  'abonnissez',
#  'abonnissiez',
#  'abonnissions',
#  'abonnissons',
#  'abonnit',
#  'abonnites',
#  'abonnons',
#  'abord',
#  'aborda',
#  'abordable',
#  'abordables',
#  'abordage',
#  'abordages',
#  'abordai',
#  'abordaient',
#  'abordais',
#  'abordait',
#  'abordames',
#  'abordant',
#  'abordas',
#  'abordasse',
#  'abordassent',
#  'abordasses',
#  'abordassiez',
#  'abordassions',
#  'abordat',
#  'abordates',
#  'aborde',
#  'abordee',
#  'abordees',
#  'abordent',
#  'aborder',
#  'abordera',
#  'aborderai',
#  'aborderaient',
#  'aborderais',
#  'aborderait',
#  'aborderas',
#  'aborderent',
#  'aborderez',
#  'aborderiez',
#  'aborderions',
#  'aborderons',
#  'aborderont',
#  'abordes',
#  'abordeur',
#  'abordeurs',
#  'abordez',
#  'abordiez',
#  'abordions',
#  'abordons',
#  'abords',
#  'aborigene',
#  'aborigenes',
#  'aborna',
#  'abornai',
#  'abornaient',
#  'abornais',
#  'abornait',
#  'abornames',
#  'abornant',
#  'abornas',
#  'abornasse',
#  'abornassent',
#  'abornasses',
#  'abornassiez',
#  'abornassions',
#  'abornat',
#  'abornates',
#  'aborne',
#  'abornee',
#  'abornees',
#  'abornement',
#  'abornements',
#  'abornent',
#  'aborner',
#  'abornera',
#  'abornerai',
#  'aborneraient',
#  'abornerais',
#  'abornerait',
#  'aborneras',
#  'abornerent',
#  'abornerez',
#  'aborneriez',
#  'abornerions',
#  'abornerons',
#  'aborneront',
#  'abornes',
#  'abornez',
#  'aborniez',
#  'abornions',
#  'abornons',
#  'abortif',
#  'abortifs',
#  'abortive',
#  'abortives',
#  'abot',
#  'aboteau',
#  'aboteaux',
#  'abots',
#  'aboucha',
#  'abouchai',
#  'abouchaient',
#  'abouchais',
#  'abouchait',
#  'abouchames',
#  'abouchant',
#  'abouchas',
#  'abouchasse',
#  'abouchassent',
#  'abouchasses',
#  'abouchassiez',
#  'abouchassions',
#  'abouchat',
#  'abouchates',
#  'abouche',
#  'abouchee',
#  'abouchees',
#  'abouchement',
#  'abouchements',
#  'abouchent',
#  'aboucher',
#  'abouchera',
#  'aboucherai',
#  ...]

# %%
dico.describe
# Out:
# <bound method NDFrame.describe of 0            aalenien
# 1          aalenienne
# 2         aaleniennes
# 3           aaleniens
# 4                 aas
#              ...
# 379029     zymotiques
# 379030         zython
# 379031        zythons
# 379032         zythum
# 379033        zythums
# Name: aa, Length: 379034, dtype: object>

# %%
dico.drop_duplicates()
# Out:
# 0            aalenien
# 1          aalenienne
# 2         aaleniennes
# 3           aaleniens
# 4                 aas
#              ...
# 379029     zymotiques
# 379030         zython
# 379031        zythons
# 379032         zythum
# 379033        zythums
# Name: aa, Length: 379033, dtype: object

# %%
def randomWord():
    return dico
randomWord()
# Out:
# 0            aalenien
# 1          aalenienne
# 2         aaleniennes
# 3           aaleniens
# 4                 aas
#              ...
# 379029     zymotiques
# 379030         zython
# 379031        zythons
# 379032         zythum
# 379033        zythums
# Name: aa, Length: 379034, dtype: object

# %%
# dictOfWords = { i : dico[i] for i in range(0, len(dico) ) }
# dictOfWords

# %%
import random
import sys


def check_if_right(word, guess, tries):
    if guess == word:
        print(f"Congratulations, you've won! The word was: {word}.")
        input("Press enter to continue...")
        return 1
    elif tries == 5:
        print(f"I'm sorry, you lost. The word was: {word}.")
        input("Press enter to continue...")
        return 0
    else:
        return 0


def get_word():
    word_file = open("sgb-words.txt", "r")
    text = word_file.read()
    text = text.split()
    num_words = len(text)
    return text[random.randint(0, num_words)]


def update_word(solution, indices): #  Updates displayed word containing correct indices
    word = ""
    for i in range(len(solution)):
        if i in indices:
            word += solution[i]
        else:
            word += "-"
    return word


def initialize_lingo_board():  # Not currently implemented; initializes bingo board
    nums_found = False
    num_list = []
    board = []
    total_count = 0
    while not nums_found:
        if total_count == 25:
            nums_found = True
        else:
            num = random.randint(0, 100)
            if num not in num_list:
                num_list.append(num)
                total_count += 1
    for i in range(total_count):
        if not i % 5:
            board.append([])
            board[i // 5].append(num_list[i])
        else:
            board[i//5].append(num_list[i])
    return board


def display_board(board):  # Not currently implemented; displays bingo board
    for i in range(len(board)):
        for j in range(len(board)):
            print(board[i][j], end="\t")
        print()


def display_guesses(guesses):
    for guess in range(1, len(guesses)):
        print(f"Guess {guess}: ", end=" ")
        display_word(guesses[guess])
        print()


def display_word(word):
    for letter in range(len(word)):
        print(f"\t{word[letter]}", end="\t")


def check_validity(guess, word):
    indices_correct = []
    if len(guess) != len(word):
        print("That's not a five letter word.")
        return indices_correct
    else:
        for letter in range(len(word)):
            if guess[letter] in word[0:] and guess[letter] == word[letter]:
                print(f"{guess[letter]} is in the right spot!")
                indices_correct.append(letter)
            elif guess[letter] in word[2:]:
                print(f"{guess[letter]} is a correct letter, but in the wrong spot!")
            else:
                print(f"{guess[letter]} is incorrect!")
    return indices_correct


def initialize_scores(players):
    scores = []
    for i in range(len(players)):
        scores.append(0)
    return scores


def initialize_players():
    num_players = int(input("How many players will there be? "))
    players = []
    for player in range(num_players):
        players.append(input(f"Please give a nickname for player {player + 1}: "))
    return players


def show_scoreboard(players, scores):
    print("Current Standings:")
    for i in range(len(players)):
        print(f"{players[i]}: {scores[i]}")
    print()


def play_game():

    board = initialize_lingo_board()
    players = initialize_players()
    scoreboard = initialize_scores(players)
    player_up = 0
    winning_score = 1

    while True:
        word = get_word()
        show_scoreboard(players, scoreboard)
        print(f"Okay {players[player_up]}, it's your turn!")
        guess_allowance = 5
        tries = 0
        guess_so_far = word[0:2] + "---"
        tot_indices_correct = [0, 1]
        guesses = [word, guess_so_far]
        for i in range(guess_allowance):
            display_guesses(guesses)
            guess = input("\nHere's your word. Make a guess! ").lower()
            guesses[i+1] = guess
            cur_indices_correct = check_validity(guess, word)
            tot_indices_correct.extend(cur_indices_correct)
            guesses.append(update_word(word, tot_indices_correct))
            tries += 1
            if check_if_right(word, guesses[i+1], tries):
                scoreboard[player_up] += 1
                break
        if winning_score in scoreboard:
            print(f"Congratulations, {players[scoreboard.index(winning_score)]}, you've won!")
            sys.exit()
        else:
            player_up += 1
            if player_up == len(players):
                player_up = 0


def main():
    print(f"Welcome to Lingo.py. The object of this game is to guess a 5-letter word in 5 tries.")
    print(f"After each guess, you are told which letters are in the correct position, which aren't, and which are just wrong.")
    play_game()
    return 0


main()
